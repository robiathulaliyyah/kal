# %%
pip install matplotlib ipympl
# Out:
# Requirement already satisfied: matplotlib in c:\python313\lib\site-packages (3.10.7)
# Requirement already satisfied: ipympl in c:\python313\lib\site-packages (0.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\python313\lib\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\python313\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\python313\lib\site-packages (from matplotlib) (2.3.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\acer\appdata\roaming\python\python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\python313\lib\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\python313\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\acer\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: ipython<10 in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipympl) (9.5.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipympl) (8.1.7)
# Requirement already satisfied: traitlets<6 in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: colorama in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipython<10->ipympl) (0.4.6)
# Requirement already satisfied: decorator in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipython<10->ipympl) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipython<10->ipympl) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipython<10->ipympl) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipython<10->ipympl) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipython<10->ipympl) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipython<10->ipympl) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipython<10->ipympl) (0.6.3)
# Requirement already satisfied: comm>=0.1.3 in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\acer\appdata\roaming\python\python313\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.15)
# Requirement already satisfied: wcwidth in c:\users\acer\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<10->ipympl) (0.2.13)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\acer\appdata\roaming\python\python313\site-packages (from jedi>=0.16->ipython<10->ipympl) (0.8.5)
# Requirement already satisfied: six>=1.5 in c:\users\acer\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\acer\appdata\roaming\python\python313\site-packages (from stack_data->ipython<10->ipympl) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\acer\appdata\roaming\python\python313\site-packages (from stack_data->ipython<10->ipympl) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\acer\appdata\roaming\python\python313\site-packages (from stack_data->ipython<10->ipympl) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

# titik dari gambar
points = {
    "A": (2, 3), "B": (2, 4), "C": (3, 4), "D": (3, 3),
    "E": (2, -3), "F": (3, -3), "G": (2, -4), "H": (3, -4),
    "I": (2, 2), "J": (3, 2), "K": (2, 1), "L": (3, 1),
    "M": (2, -1), "N": (3, -1), "O": (2, -2), "P": (3, -2)
}

# kelompok kotak
boxes = [
    ["A", "B", "C", "D", "A"],
    ["E", "F", "H", "G", "E"],
    ["I", "J", "L", "K", "I"],
    ["M", "N", "P", "O", "M"]
]

fig, ax = plt.subplots(figsize=(6,6))

def update(frame):
    ax.clear()

    # transformasi mendekati sumbu x
    scale_y = 1 - frame / 100

    transformed = {}

    # ubah posisi titik
    for nama, (x, y) in points.items():
        y_baru = y * scale_y
        transformed[nama] = (x, y_baru)

    # gambar kotak
    for box in boxes:
        x_vals = []
        y_vals = []

        for titik in box:
            x, y = transformed[titik]
            x_vals.append(x)
            y_vals.append(y)

        ax.plot(x_vals, y_vals, color="blue", linewidth=2)

    # gambar titik + nama
    for nama, (x, y) in transformed.items():
        ax.scatter(x, y, color="red")
        ax.text(x + 0.05, y + 0.05, nama)

    # sumbu
    ax.axhline(0, color="black")
    ax.axvline(0, color="black")

    ax.set_xlim(0, 5)
    ax.set_ylim(-5, 5)

    ax.grid(True)
    ax.set_title("Transformasi Mendekati Sumbu X")

# =========================
# MEMBUAT ANIMASI
# =========================
ani = animation.FuncAnimation(
    fig,
    update,
    frames=101,
    interval=50,
    repeat=True
)

# =========================
# SIMPAN MENJADI HTML
# =========================
html_string = ani.to_jshtml()

with open("animasi.html", "w", encoding="utf-8") as f:
    f.write(f"""
    <html>
    <head>
        <title>Animasi Transformasi</title>
    </head>
    <body>
        <h2>Transformasi Mendekati Sumbu X</h2>
        {html_string}
    </body>
    </html>
    """)

print("File animasi.html berhasil dibuat")
# Out:
# File animasi.html berhasil dibuat
