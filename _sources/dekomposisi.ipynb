# %% [markdown]
# ## MEMBUAT MATRIX 4*4 MENCARI  DEKOMPOSISI Q&R

# %% [markdown]
# <p align="center">
#   <img src="hal 1.jpeg" width="450">
# </p>
#
# ---
#
# <p align="center">
#   <img src="hal 2.jpeg" width="450">
# </p>
#
# ---
#
# <p align="center">
#   <img src="hal 3.jpeg" width="450">
# </p>
#
# ---
#
# <p align="center">
#   <img src="hal 4.jpeg" width="450">
# </p>
